# %% [markdown]
# <a id='top'></a>
#
# ------
#
#
# # 2020-0120 C6 Data Science Pipeline and Critical Thinking
#
# =====
#
# **Instructors**: Srikant Datar, Hanspeter Pfister, Joe Blitzstein <br/>
# **Author**: Rashmi Banthia
#
# --------

# %%
import pandas as pd
import numpy as np
import graphviz 
from sklearn.tree import DecisionTreeClassifier, export_graphviz

from sklearn import tree

# %% [markdown]
# ## 24 data points

# %%
data = pd.read_csv('DT.csv',usecols=['Income','Credit','Repay']) #24 Data points
data
# Out:
#     Income  Credit  Repay
# 0       85     620      1
# 1      108     648      1
# 2       60     682      1
# 3      110     701      1
# 4       69     731      1
# 5       81     716      1
# 6       93     749      1
# 7       61     752      1
# 8       65     767      1
# 9       52     788      1
# 10      83     796      1
# 11      87     840      1
# 12      51     524      0
# 13      63     548      0
# 14      59     596      0
# 15      47     602      0
# 16      64     627      0
# 17      84     640      0
# 18      49     638      0
# 19      66     667      0
# 20      33     680      0
# 21      75     708      0
# 22      43     730      0
# 23      53     748      0

# %%
clf = DecisionTreeClassifier(random_state=10)
clf = clf.fit(data[['Income','Credit']], data.Repay)

# %%
dot_data = export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph

# %% [markdown]
# Lets consider the first box of values -
#
# - X[1] = This refers to feature 'Credit'  (681.0 is value for split)
# - samples = 24  Total number of samples in dataset
# - Gini = 1 - (12/24)\*(12/24) - (12/24)\*(12/24)  = 0.5
# - Value = [12, 12] = We have 12 repay values as 0 and 12 repay values as 1 in the dataset.
#
#
# Next box (Left) -
# - X[0] = This refers to feature 'Income'  (84.5 is income value for split)
# - samples = 11 This is number of samples where Credit <= 681.0
# - Gini = 1 - (9/11)\*(9/11) - (2/11)\*(2/11) = 0.2975
# - Value = [9,2] = Out of 11 samples we have 2 Repay(1) and 9 Repay(0).
#
# Next box (Right) -
# - X[0] - This refers to feature 'Income' (56.5 is income value for split)
# - samples = 13 This is number of samples where Credit > 681.0
# - Gini = 1 - (3/13)\*(3/13) - (10/13)\*(10/13) = 0.35502
# - Value = [3,10] = Out of 13 samples we have 10 Repay(1) and 3 Repay(0).
#
# ... and so on and on.
